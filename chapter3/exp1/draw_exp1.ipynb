# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

categories = ['plain', 'LDP', 'PHE', 'Semi2k', 'TEE']

values1 = [30.902023553848267, 34.65807223320007, 1983.3110427856445, 974.8450841903687, 51.8430219264593]  # mnist
values1 = np.array(values1) / 3
print(values1)

['plain', 'ldp', 'ss', 'phe']
values2 = [13.323332, 15.9675234, 1977.34248, 807.3423413, 37.67352]   # cifar result
width = 0.45

a = range(5)
x1 = [i-width for i in a]
x2 = a
# x3 = [i+width for i in a]

# plt.bar(categories, values1, color='black')
plt.bar(x1, values1, width=width, label='mnist')

plt.bar(x2, values2, width=width, label='cifar-10')

plt.xlabel('Aggregation Type')
plt.ylabel('Cost-Time per epoch')
# plt.title('聚合')
plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0fs'))
plt.xticks(a, categories)
plt.legend()
plt.show()
# Out:
# [ 10.30067452  11.55269074 661.10368093 324.9483614   17.28100731]
