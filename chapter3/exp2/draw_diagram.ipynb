# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# print(matplotlib.matplotlib_fname())

x_values = [1, 2, 3, 4, 5, 6]
# layered agg
result1 = [1.0608723163604736, 1.2171602249145508, 2.258134603500366, 4.6717751026153564, 9.567161560058594, 50.33025050163269]

# full agg
result2 = [2.4093017578125,  7.436727285385132, 10.224837303161621, 38.355350971221924, 62.35246729850769, 254.4940493106842]

plt.plot(x_values, result1, label='分层聚合', marker='o', markersize=6,markeredgecolor='black')
plt.plot(x_values, result2, label='普通聚合', marker='x', markersize=6,markeredgecolor='black', markerfacecolor='steelblue')

custom_ticks = [1, 5, 10, 50, 100, 500]
plt.xticks(x_values, custom_ticks)

# for a, b in zip(x_values, result1):
#     plt.text(a, b, round(b,2), ha='center', va='bottom', fontsize=10)

# for a, b in zip(x_values, result2):
#     plt.text(a, b, round(b,2), ha='center', va='bottom', fontsize=10)

plt.title('分层聚合优化效率对比')
plt.xlabel('客户端数量')
plt.ylabel("时间(秒)")

plt.legend()
plt.show()
